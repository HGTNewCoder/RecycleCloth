# %%
import numpy as np
import pandas as pd

# %%
DOWNLOADED_DATASET_PATH = "/home/ubuntu/iai2o/Datasets/"
myFile2 = pd.read_json(DOWNLOADED_DATASET_PATH + 'DeepFashion2/deepfashion2_original_images/train/annos/039350.json').drop(columns='pair_id')

# %%
myFile2[myFile2['source']=='shop']
# Out:
#                                                            item2 source  \
# segmentation   [[360, 172, 364, 166, 371, 163, 325, 168, 299,...   shop
# scale                                                          2   shop
# viewpoint                                                      2   shop
# zoom_in                                                        1   shop
# landmarks      [387, 176, 1, 371, 163, 1, 364, 166, 1, 360, 1...   shop
# style                                                          0   shop
# bounding_box                                [227, 155, 442, 381]   shop
# category_id                                                    4   shop
# occlusion                                                      2   shop
# category_name                                long sleeve outwear   shop
#
#                                                            item1
# segmentation   [[381, 306, 334, 289, 297, 266, 261, 350, 225,...
# scale                                                          2
# viewpoint                                                      2
# zoom_in                                                        1
# landmarks      [297, 266, 1, 334, 289, 1, 381, 306, 1, 261, 3...
# style                                                          2
# bounding_box                                [209, 263, 387, 539]
# category_id                                                    8
# occlusion                                                      2
# category_name                                           trousers
